# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# 51 out of 57 total examples

names = ['!GCM_1_Stan', '!GCM_2_Stan', '!GCM_3_optimized_Stan', '!GCM_3_Stan', 'Ability_Stan', 'BART_1_Stan', 'BART_2_Stan', 'ChangeDetection_Stan', 'ChaSaSoon_Stan', 'Correlation_1_Stan', 'Correlation_2_Stan', 'Exams_1_Stan', 'Exams_2_Stan', 'Extraversion_Stan', 'Gaussian_Stan', 'Geurts_Stan', 'GeurtsOrderRestricted_Stan', 'IQ_Stan', 'Kappa_Stan', 'Malingering_1_Stan', 'Malingering_2_Stan', 'MPT_1_Stan', 'MPT_5_Stan', 'NumberConcept_1_Stan', 'NumberConcept_2_Stan', 'NumberConcept_3_Stan', 'OneSampleOrderRestricted_Stan', 'OptionalStopping_Answer_1_Stan', 'OptionalStopping_Stan', 'Planes_Stan', 'Pledgers_1_Stan', 'Pledgers_2_Stan', 'PsychophysicalFunction1_Stan', 'Rate_1_Stan', 'Rate_2_Stan', 'Rate_3_Stan', 'Rate_4_Stan', 'Rate_5_Stan', 'Retention_1_Stan', 'Retention_2_Stan', 'Retention_3_Stan', 'SDT_1_Stan', 'SDT_2_Stan', 'SDT_3_Stan', 'SevenScientists_Stan', 'Stop_Stan', 'Survey_Stan', 'TTB_Stan', 'TwentyQuestions_Stan', 'TwoSample_Stan', 'Zeelenberg_Stan']
inference_time = [72.97, 94.61, 98.96, 99.25, 81.51, 75.0, 95.83, 95.62, 68.42, 82.86, 91.84, 75.26, 99.83, 93.99, 67.86, 94.2, 95.82, 65.45, 66.07, 67.21, 91.93, 83.19, 59.81, 96.69, 96.23, 98.56, 59.24, 55.68, 76.24, 75.0, 67.55, 67.53, 88.54, 72.06, 70.31, 66.67, 65.67, 63.79, 79.8, 86.96, 91.14, 65.88, 93.65, 98.8, 78.72, 76.56, 96.46, 70.91, 82.67, 68.57, 97.05]
sampling_time = [35.14, 87.13, 97.69, 98.3, 60.5, 45.45, 89.71, 89.4, 22.81, 58.1, 80.82, 47.42, 99.65, 89.15, 23.21, 89.86, 93.65, 20.0, 19.64, 24.59, 83.54, 58.82, 33.64, 93.39, 92.6, 97.39, 42.04, 40.54, 49.5, 38.89, 50.33, 59.42, 75.52, 33.82, 29.69, 23.33, 26.87, 18.97, 54.55, 68.12, 78.06, 34.12, 85.71, 97.0, 50.0, 53.12, 91.6, 44.55, 66.0, 45.71, 94.8]

fig, ax = plt.subplots(figsize=(20,5))
#sorted_names = [x for (y,x) in sorted(zip(time,names))]
plt.bar(range(len(inference_time)), inference_time, width=0.8)
plt.bar([len(inference_time)], np.mean(inference_time), width=0.8,color='r')
plt.yticks(fontsize = 20)
ax.set_xticks(range(len(inference_time)+1))
names.append('Avg')
ax.set_xticklabels(names, rotation=90,fontsize=20)
ax.set_title('inference %', fontsize = 20)
ax.grid()

# %%
# 51 out of 57 total examples

names = ['!GCM_1_Stan', '!GCM_2_Stan', '!GCM_3_optimized_Stan', '!GCM_3_Stan', 'Ability_Stan', 'BART_1_Stan', 'BART_2_Stan', 'ChangeDetection_Stan', 'ChaSaSoon_Stan', 'Correlation_1_Stan', 'Correlation_2_Stan', 'Exams_1_Stan', 'Exams_2_Stan', 'Extraversion_Stan', 'Gaussian_Stan', 'Geurts_Stan', 'GeurtsOrderRestricted_Stan', 'IQ_Stan', 'Kappa_Stan', 'Malingering_1_Stan', 'Malingering_2_Stan', 'MPT_1_Stan', 'MPT_5_Stan', 'NumberConcept_1_Stan', 'NumberConcept_2_Stan', 'NumberConcept_3_Stan', 'OneSampleOrderRestricted_Stan', 'OptionalStopping_Answer_1_Stan', 'OptionalStopping_Stan', 'Planes_Stan', 'Pledgers_1_Stan', 'Pledgers_2_Stan', 'PsychophysicalFunction1_Stan', 'Rate_1_Stan', 'Rate_2_Stan', 'Rate_3_Stan', 'Rate_4_Stan', 'Rate_5_Stan', 'Retention_1_Stan', 'Retention_2_Stan', 'Retention_3_Stan', 'SDT_1_Stan', 'SDT_2_Stan', 'SDT_3_Stan', 'SevenScientists_Stan', 'Stop_Stan', 'Survey_Stan', 'TTB_Stan', 'TwentyQuestions_Stan', 'TwoSample_Stan', 'Zeelenberg_Stan']
inference_time = [72.97, 94.61, 98.96, 99.25, 81.51, 75.0, 95.83, 95.62, 68.42, 82.86, 91.84, 75.26, 99.83, 93.99, 67.86, 94.2, 95.82, 65.45, 66.07, 67.21, 91.93, 83.19, 59.81, 96.69, 96.23, 98.56, 59.24, 55.68, 76.24, 75.0, 67.55, 67.53, 88.54, 72.06, 70.31, 66.67, 65.67, 63.79, 79.8, 86.96, 91.14, 65.88, 93.65, 98.8, 78.72, 76.56, 96.46, 70.91, 82.67, 68.57, 97.05]
sampling_time = [35.14, 87.13, 97.69, 98.3, 60.5, 45.45, 89.71, 89.4, 22.81, 58.1, 80.82, 47.42, 99.65, 89.15, 23.21, 89.86, 93.65, 20.0, 19.64, 24.59, 83.54, 58.82, 33.64, 93.39, 92.6, 97.39, 42.04, 40.54, 49.5, 38.89, 50.33, 59.42, 75.52, 33.82, 29.69, 23.33, 26.87, 18.97, 54.55, 68.12, 78.06, 34.12, 85.71, 97.0, 50.0, 53.12, 91.6, 44.55, 66.0, 45.71, 94.8]

fig, ax = plt.subplots(figsize=(20,5))
sorted_names = [x for (y,x) in sorted(zip(inference_time,names))]
plt.bar(range(len(inference_time)), sorted(inference_time), width=0.8)
plt.bar([len(inference_time)], np.mean(inference_time), width=0.8,color='r')
plt.yticks(fontsize = 20)
ax.set_xticks(range(len(inference_time)+1))
sorted_names.append('Avg')
ax.set_xticklabels(sorted_names, rotation=90,fontsize=20)
ax.set_title('inference %', fontsize = 20)
ax.grid()

# %%
# 51 out of 57 total examples

names = ['!GCM_1_Stan', '!GCM_2_Stan', '!GCM_3_optimized_Stan', '!GCM_3_Stan', 'Ability_Stan', 'BART_1_Stan', 'BART_2_Stan', 'ChangeDetection_Stan', 'ChaSaSoon_Stan', 'Correlation_1_Stan', 'Correlation_2_Stan', 'Exams_1_Stan', 'Exams_2_Stan', 'Extraversion_Stan', 'Gaussian_Stan', 'Geurts_Stan', 'GeurtsOrderRestricted_Stan', 'IQ_Stan', 'Kappa_Stan', 'Malingering_1_Stan', 'Malingering_2_Stan', 'MPT_1_Stan', 'MPT_5_Stan', 'NumberConcept_1_Stan', 'NumberConcept_2_Stan', 'NumberConcept_3_Stan', 'OneSampleOrderRestricted_Stan', 'OptionalStopping_Answer_1_Stan', 'OptionalStopping_Stan', 'Planes_Stan', 'Pledgers_1_Stan', 'Pledgers_2_Stan', 'PsychophysicalFunction1_Stan', 'Rate_1_Stan', 'Rate_2_Stan', 'Rate_3_Stan', 'Rate_4_Stan', 'Rate_5_Stan', 'Retention_1_Stan', 'Retention_2_Stan', 'Retention_3_Stan', 'SDT_1_Stan', 'SDT_2_Stan', 'SDT_3_Stan', 'SevenScientists_Stan', 'Stop_Stan', 'Survey_Stan', 'TTB_Stan', 'TwentyQuestions_Stan', 'TwoSample_Stan', 'Zeelenberg_Stan']
inference_time = [72.97, 94.61, 98.96, 99.25, 81.51, 75.0, 95.83, 95.62, 68.42, 82.86, 91.84, 75.26, 99.83, 93.99, 67.86, 94.2, 95.82, 65.45, 66.07, 67.21, 91.93, 83.19, 59.81, 96.69, 96.23, 98.56, 59.24, 55.68, 76.24, 75.0, 67.55, 67.53, 88.54, 72.06, 70.31, 66.67, 65.67, 63.79, 79.8, 86.96, 91.14, 65.88, 93.65, 98.8, 78.72, 76.56, 96.46, 70.91, 82.67, 68.57, 97.05]
sampling_time = [35.14, 87.13, 97.69, 98.3, 60.5, 45.45, 89.71, 89.4, 22.81, 58.1, 80.82, 47.42, 99.65, 89.15, 23.21, 89.86, 93.65, 20.0, 19.64, 24.59, 83.54, 58.82, 33.64, 93.39, 92.6, 97.39, 42.04, 40.54, 49.5, 38.89, 50.33, 59.42, 75.52, 33.82, 29.69, 23.33, 26.87, 18.97, 54.55, 68.12, 78.06, 34.12, 85.71, 97.0, 50.0, 53.12, 91.6, 44.55, 66.0, 45.71, 94.8]
sampling_inference = [0.48156776757571607, 0.9209385900010569, 0.9871665319320938, 0.9904282115869018, 0.7422402159244263, 0.606, 0.936136909109882, 0.9349508471031165, 0.3333820520315697, 0.701182717837316, 0.8800087108013936, 0.6300823810789263, 0.9981969347891416, 0.9485051601234175, 0.3420277040966696, 0.953927813163482, 0.977353370903778, 0.30557677616501144, 0.297260481307704, 0.3658681743788127, 0.9087349069944523, 0.7070561365548744, 0.5624477512121718, 0.9658703071672355, 0.9622778759222694, 0.9881290584415584, 0.7096556380823767, 0.72808908045977, 0.6492654774396642, 0.5185333333333333, 0.7450777202072539, 0.8799052273063823, 0.8529478201942624, 0.46933111296142105, 0.42227279192149053, 0.3499325033748312, 0.40916704735800213, 0.29738203480169306, 0.6835839598997494, 0.783348666053358, 0.8564845292955893, 0.5179113539769278, 0.9152162306460223, 0.9817813765182186, 0.6351626016260162, 0.6938349007314524, 0.9496164213145345, 0.6282611761387674, 0.7983549050441514, 0.6666180545428031, 0.9768160741885626]



fig, ax = plt.subplots(figsize=(20,5))
sorted_names = [x for (y,x) in sorted(zip(sampling_inference,names))]
plt.bar(range(len(sampling_inference)), sorted(sampling_inference), width=0.8)
plt.bar([len(sampling_inference)], np.mean(sampling_inference), width=0.8,color='r')
plt.yticks(fontsize = 20)
ax.set_xticks(range(len(inference_time)+1))
sorted_names.append('Avg')
ax.set_xticklabels(sorted_names, rotation=90,fontsize=20)
ax.set_title('sampling / inference', fontsize = 20)
ax.grid()

# %%
# 51 out of 57 total examples

names = ['!GCM_1_Stan', '!GCM_2_Stan', '!GCM_3_optimized_Stan', '!GCM_3_Stan', 'Ability_Stan', 'BART_1_Stan', 'BART_2_Stan', 'ChangeDetection_Stan', 'ChaSaSoon_Stan', 'Correlation_1_Stan', 'Correlation_2_Stan', 'Exams_1_Stan', 'Exams_2_Stan', 'Extraversion_Stan', 'Gaussian_Stan', 'Geurts_Stan', 'GeurtsOrderRestricted_Stan', 'IQ_Stan', 'Kappa_Stan', 'Malingering_1_Stan', 'Malingering_2_Stan', 'MPT_1_Stan', 'MPT_5_Stan', 'NumberConcept_1_Stan', 'NumberConcept_2_Stan', 'NumberConcept_3_Stan', 'OneSampleOrderRestricted_Stan', 'OptionalStopping_Answer_1_Stan', 'OptionalStopping_Stan', 'Planes_Stan', 'Pledgers_1_Stan', 'Pledgers_2_Stan', 'PsychophysicalFunction1_Stan', 'Rate_1_Stan', 'Rate_2_Stan', 'Rate_3_Stan', 'Rate_4_Stan', 'Rate_5_Stan', 'Retention_1_Stan', 'Retention_2_Stan', 'Retention_3_Stan', 'SDT_1_Stan', 'SDT_2_Stan', 'SDT_3_Stan', 'SevenScientists_Stan', 'Stop_Stan', 'Survey_Stan', 'TTB_Stan', 'TwentyQuestions_Stan', 'TwoSample_Stan', 'Zeelenberg_Stan']
inference_time = [72.97, 94.61, 98.96, 99.25, 81.51, 75.0, 95.83, 95.62, 68.42, 82.86, 91.84, 75.26, 99.83, 93.99, 67.86, 94.2, 95.82, 65.45, 66.07, 67.21, 91.93, 83.19, 59.81, 96.69, 96.23, 98.56, 59.24, 55.68, 76.24, 75.0, 67.55, 67.53, 88.54, 72.06, 70.31, 66.67, 65.67, 63.79, 79.8, 86.96, 91.14, 65.88, 93.65, 98.8, 78.72, 76.56, 96.46, 70.91, 82.67, 68.57, 97.05]
sampling_time = [35.14, 87.13, 97.69, 98.3, 60.5, 45.45, 89.71, 89.4, 22.81, 58.1, 80.82, 47.42, 99.65, 89.15, 23.21, 89.86, 93.65, 20.0, 19.64, 24.59, 83.54, 58.82, 33.64, 93.39, 92.6, 97.39, 42.04, 40.54, 49.5, 38.89, 50.33, 59.42, 75.52, 33.82, 29.69, 23.33, 26.87, 18.97, 54.55, 68.12, 78.06, 34.12, 85.71, 97.0, 50.0, 53.12, 91.6, 44.55, 66.0, 45.71, 94.8]

fig, ax = plt.subplots(figsize=(20,5))
sorted_names = [x for (y,x) in sorted(zip(sampling_time,names))]
plt.bar(range(len(sampling_time)), sorted(sampling_time), width=0.8)
plt.bar([len(sampling_time)], np.mean(sampling_time), width=0.8,color='r')
plt.yticks(fontsize = 20)
ax.set_xticks(range(len(sampling_time)+1))
sorted_names.append('Avg')
ax.set_xticklabels(sorted_names, rotation=90,fontsize=20)
ax.set_title('sampling %', fontsize = 20)
ax.grid()

# %%
names = ['!GCM_1_Stan', '!GCM_2_Stan', '!GCM_3_optimized_Stan', '!GCM_3_Stan', 'Ability_Stan', 'BART_1_Stan', 'BART_2_Stan', 'ChangeDetection_Stan', 'ChaSaSoon_Stan', 'Correlation_1_Stan', 'Correlation_2_Stan', 'Exams_1_Stan', 'Exams_2_Stan', 'Extraversion_Stan', 'Gaussian_Stan', 'Geurts_Stan', 'GeurtsOrderRestricted_Stan', 'IQ_Stan', 'Kappa_Stan', 'Malingering_1_Stan', 'Malingering_2_Stan', 'MPT_1_Stan', 'MPT_5_Stan', 'NumberConcept_1_Stan', 'NumberConcept_2_Stan', 'NumberConcept_3_Stan', 'OneSampleOrderRestricted_Stan', 'OptionalStopping_Answer_1_Stan', 'OptionalStopping_Stan', 'Planes_Stan', 'Pledgers_1_Stan', 'Pledgers_2_Stan', 'PsychophysicalFunction1_Stan', 'Rate_1_Stan', 'Rate_2_Stan', 'Rate_3_Stan', 'Rate_4_Stan', 'Rate_5_Stan', 'Retention_1_Stan', 'Retention_2_Stan', 'Retention_3_Stan', 'SDT_1_Stan', 'SDT_2_Stan', 'SDT_3_Stan', 'SevenScientists_Stan', 'Stop_Stan', 'Survey_Stan', 'TTB_Stan', 'TwentyQuestions_Stan', 'TwoSample_Stan', 'Zeelenberg_Stan']
inference_time = [72.97, 94.61, 98.96, 99.25, 81.51, 75.0, 95.83, 95.62, 68.42, 82.86, 91.84, 75.26, 99.83, 93.99, 67.86, 94.2, 95.82, 65.45, 66.07, 67.21, 91.93, 83.19, 59.81, 96.69, 96.23, 98.56, 59.24, 55.68, 76.24, 75.0, 67.55, 67.53, 88.54, 72.06, 70.31, 66.67, 65.67, 63.79, 79.8, 86.96, 91.14, 65.88, 93.65, 98.8, 78.72, 76.56, 96.46, 70.91, 82.67, 68.57, 97.05]
sampling_time = [35.14, 87.13, 97.69, 98.3, 60.5, 45.45, 89.71, 89.4, 22.81, 58.1, 80.82, 47.42, 99.65, 89.15, 23.21, 89.86, 93.65, 20.0, 19.64, 24.59, 83.54, 58.82, 33.64, 93.39, 92.6, 97.39, 42.04, 40.54, 49.5, 38.89, 50.33, 59.42, 75.52, 33.82, 29.69, 23.33, 26.87, 18.97, 54.55, 68.12, 78.06, 34.12, 85.71, 97.0, 50.0, 53.12, 91.6, 44.55, 66.0, 45.71, 94.8]
total_time = [1.4800602987529121, 6.68005496247754, 44.09862570735651, 61.1183879093199, 2.3800760642865906, 1.76, 8.160283835959511, 8.680192428362268, 1.1400175387313651, 2.0999275887038378, 4.899825783972125, 1.9399415360085037, 294.92136632274867, 10.320246834769655, 1.1199528440907751, 12.420382165605096, 24.87998330202463, 1.1000763941940412, 1.1200242167398216, 1.2200565392054754, 6.439682367018383, 2.3800937612693835, 2.140110349439893, 16.94073844244493, 14.860230697287747, 49.83766233766234, 3.1397704253882512, 3.699712643678161, 2.0199370409234, 1.44, 3.0199851961509996, 6.160225085147342, 3.8400722837135755, 1.359977796280877, 1.2800455127293415, 1.19994000299985, 1.3400335008375208, 1.1600564351779277, 1.9799498746867168, 2.7598896044158234, 4.739960500329164, 1.7000607164541595, 6.300053390282968, 30.0, 1.8800813008130082, 2.560083594566353, 10.719469210035248, 2.1999717952333944, 2.9998790371355994, 2.1000437509114773, 23.08088614116435]
print(max(total_time))

fig, (ax, ax2) = plt.subplots(2, 1, figsize=(20,5), sharex=True)



ax.bar(range(len(total_time)), total_time, width=0.8)
ax.bar([len(total_time)], np.mean(total_time), width=0.8,color='r')

plt.yticks(fontsize = 20)
ax.set_ylim(10, 300)  # outliers only
ax.set_title('Total Latency (sec)', fontsize = 20)
ax.spines['bottom'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop='off')  # don't put tick labels at the top
ax.yaxis.set_tick_params(labelsize=20)

ax2.bar(range(len(total_time)), total_time, width=0.8)
ax2.bar([len(total_time)], np.mean(total_time), width=0.8,color='r')
ax2.set_ylim(0, 10)  # most of the data
ax2.spines['top'].set_visible(False)
ax2.xaxis.tick_bottom()
ax2.set_xticks(range(len(total_time)+1))
names.append('Avg')
ax2.set_xticklabels(names, rotation=90, fontsize=20)
plt.yticks(fontsize = 20)
# Out:
# 294.92136632274867
# (array([  0.,   2.,   4.,   6.,   8.,  10.]),
#  <a list of 6 Text yticklabel objects>)

# %%
names = ['!GCM_1_Stan', '!GCM_2_Stan', '!GCM_3_optimized_Stan', '!GCM_3_Stan', 'Ability_Stan', 'BART_1_Stan', 'BART_2_Stan', 'ChangeDetection_Stan', 'ChaSaSoon_Stan', 'Correlation_1_Stan', 'Correlation_2_Stan', 'Exams_1_Stan', 'Exams_2_Stan', 'Extraversion_Stan', 'Gaussian_Stan', 'Geurts_Stan', 'GeurtsOrderRestricted_Stan', 'IQ_Stan', 'Kappa_Stan', 'Malingering_1_Stan', 'Malingering_2_Stan', 'MPT_1_Stan', 'MPT_5_Stan', 'NumberConcept_1_Stan', 'NumberConcept_2_Stan', 'NumberConcept_3_Stan', 'OneSampleOrderRestricted_Stan', 'OptionalStopping_Answer_1_Stan', 'OptionalStopping_Stan', 'Planes_Stan', 'Pledgers_1_Stan', 'Pledgers_2_Stan', 'PsychophysicalFunction1_Stan', 'Rate_1_Stan', 'Rate_2_Stan', 'Rate_3_Stan', 'Rate_4_Stan', 'Rate_5_Stan', 'Retention_1_Stan', 'Retention_2_Stan', 'Retention_3_Stan', 'SDT_1_Stan', 'SDT_2_Stan', 'SDT_3_Stan', 'SevenScientists_Stan', 'Stop_Stan', 'Survey_Stan', 'TTB_Stan', 'TwentyQuestions_Stan', 'TwoSample_Stan', 'Zeelenberg_Stan']
inference_time = [72.97, 94.61, 98.96, 99.25, 81.51, 75.0, 95.83, 95.62, 68.42, 82.86, 91.84, 75.26, 99.83, 93.99, 67.86, 94.2, 95.82, 65.45, 66.07, 67.21, 91.93, 83.19, 59.81, 96.69, 96.23, 98.56, 59.24, 55.68, 76.24, 75.0, 67.55, 67.53, 88.54, 72.06, 70.31, 66.67, 65.67, 63.79, 79.8, 86.96, 91.14, 65.88, 93.65, 98.8, 78.72, 76.56, 96.46, 70.91, 82.67, 68.57, 97.05]
sampling_time = [35.14, 87.13, 97.69, 98.3, 60.5, 45.45, 89.71, 89.4, 22.81, 58.1, 80.82, 47.42, 99.65, 89.15, 23.21, 89.86, 93.65, 20.0, 19.64, 24.59, 83.54, 58.82, 33.64, 93.39, 92.6, 97.39, 42.04, 40.54, 49.5, 38.89, 50.33, 59.42, 75.52, 33.82, 29.69, 23.33, 26.87, 18.97, 54.55, 68.12, 78.06, 34.12, 85.71, 97.0, 50.0, 53.12, 91.6, 44.55, 66.0, 45.71, 94.8]
total_time = [1.4800602987529121, 6.68005496247754, 44.09862570735651, 61.1183879093199, 2.3800760642865906, 1.76, 8.160283835959511, 8.680192428362268, 1.1400175387313651, 2.0999275887038378, 4.899825783972125, 1.9399415360085037, 294.92136632274867, 10.320246834769655, 1.1199528440907751, 12.420382165605096, 24.87998330202463, 1.1000763941940412, 1.1200242167398216, 1.2200565392054754, 6.439682367018383, 2.3800937612693835, 2.140110349439893, 16.94073844244493, 14.860230697287747, 49.83766233766234, 3.1397704253882512, 3.699712643678161, 2.0199370409234, 1.44, 3.0199851961509996, 6.160225085147342, 3.8400722837135755, 1.359977796280877, 1.2800455127293415, 1.19994000299985, 1.3400335008375208, 1.1600564351779277, 1.9799498746867168, 2.7598896044158234, 4.739960500329164, 1.7000607164541595, 6.300053390282968, 30.0, 1.8800813008130082, 2.560083594566353, 10.719469210035248, 2.1999717952333944, 2.9998790371355994, 2.1000437509114773, 23.08088614116435]
print(max(total_time))

fig, (ax, ax2) = plt.subplots(2, 1, figsize=(20,5), sharex=True)

sorted_names = [x for (y,x) in sorted(zip(total_time,names))]

ax.bar(range(len(total_time)), sorted(total_time), width=0.8)
ax.bar([len(total_time)], np.mean(total_time), width=0.8,color='r')
plt.yticks(fontsize = 20)
ax.set_ylim(10, 300)  # outliers only
ax.set_title('Total Latency (sec)', fontsize = 20)
ax.spines['bottom'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop='off')  # don't put tick labels at the top
ax.yaxis.set_tick_params(labelsize=20)

ax2.bar(range(len(total_time)), sorted(total_time), width=0.8)
ax2.bar([len(total_time)], np.mean(total_time), width=0.8,color='r')
ax2.set_ylim(0, 10)  # most of the data
ax2.spines['top'].set_visible(False)
ax2.xaxis.tick_bottom()
ax2.set_xticks(range(len(total_time)+1))
names.append('Avg')
ax2.set_xticklabels(names, rotation=90, fontsize=20)
plt.yticks(fontsize = 20)
# Out:
# 294.92136632274867
# (array([  0.,   2.,   4.,   6.,   8.,  10.]),
#  <a list of 6 Text yticklabel objects>)
